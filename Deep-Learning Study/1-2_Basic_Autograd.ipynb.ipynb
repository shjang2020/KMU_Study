# %%
import torch

# %% [markdown]
# # Scalar
# - 상수값
# - `torch.tensor` 함수를 통해 정의할 수 있음

# %%
scalar1 = torch.tensor([1.])
print(scalar1)
# Out:
# tensor([1.])

# %%
scalar2 = torch.tensor([3.])    
print(scalar2)
# Out:
# tensor([3.])

# %% [markdown]
# - 정의한 `tensor`(상수값)을 갖고 사칙연산 수행 가능

# %%
add_scalar = scalar1 + scalar2
print(add_scalar)
# Out:
# tensor([4.])

# %%
sub_scalar = scalar1 - scalar2
print(sub_scalar)
# Out:
# tensor([-2.])

# %%
mul_scalar = scalar1 * scalar2
print(mul_scalar)
# Out:
# tensor([3.])

# %%
div_scalar = scalar1 / scalar2
print(div_scalar)
# Out:
# tensor([0.3333])

# %% [markdown]
# - `torch` 모듈의 내장 함수를 통해서도 사칙연산 수행 가능

# %%
torch.add(scalar1, scalar2)
# Out:
# tensor([4.])

# %%
torch.sub(scalar1, scalar2)
# Out:
# tensor([-2.])

# %%
torch.mul(scalar1, scalar2)
# Out:
# tensor([3.])

# %%
torch.div(scalar1, scalar2)
# Out:
# tensor([0.3333])

# %% [markdown]
# # Vector
# - `torch.tensor`를 통해 벡터를 정의하는 것 또한 가능

# %%
vector1 = torch.tensor([1., 2., 3.])
print(vector1)
# Out:
# tensor([1., 2., 3.])

# %%
vector2 = torch.tensor([4., 5., 6.])
print(vector2)
# Out:
# tensor([4., 5., 6.])

# %%
add_vector = vector1 + vector2
print(add_vector)
# Out:
# tensor([5., 7., 9.])

# %%
sub_vector = vector1 - vector2
print(sub_vector)
# Out:
# tensor([-3., -3., -3.])

# %%
mul_vector = vector1 * vector2
print(mul_vector)
# Out:
# tensor([ 4., 10., 18.])

# %%
div_vector = vector1 / vector2
print(div_vector)
# Out:
# tensor([0.2500, 0.4000, 0.5000])

# %%
torch.add(vector1, vector2)
# Out:
# tensor([5., 7., 9.])

# %%
torch.sub(vector1, vector2)
# Out:
# tensor([-3., -3., -3.])

# %%
torch.mul(vector1, vector2)
# Out:
# tensor([ 4., 10., 18.])

# %%
torch.div(vector1, vector2)
# Out:
# tensor([0.2500, 0.4000, 0.5000])

# %%
torch.dot(vector1, vector2) # 벡터의 내적
# Out:
# tensor(32.)

# %% [markdown]
# # Matrix
# - 행렬 (2개 이상의 벡터로 구성된 선형 대수의 기본 단위)
# - `torch.tensor`를 통해 행렬 정의 가능

# %%
matrix1 = torch.tensor([[1., 2.], 
                        [3., 4.]])
print(matrix1)
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %%
matrix2 = torch.tensor([[5., 6.], 
                        [7., 8.]])
print(matrix2)
# Out:
# tensor([[5., 6.],
#         [7., 8.]])

# %% [markdown]
# - Scalar, Vector tensor와 같은 방식으로 사칙연산 수행 가능

# %%
sum_matrix = matrix1 + matrix2
print(sum_matrix)
# Out:
# tensor([[ 6.,  8.],
#         [10., 12.]])

# %%
sub_matrix = matrix1 - matrix2
print(sub_matrix)
# Out:
# tensor([[-4., -4.],
#         [-4., -4.]])

# %% [markdown]
# - `*` 와 `/`의 경우, 행렬의 같은 위치에 존재하는 값들끼리 연산이 수행됨 (element-wise operation)

# %%
mul_matrix = matrix1 * matrix2
print(mul_matrix)
# Out:
# tensor([[ 5., 12.],
#         [21., 32.]])

# %%
div_matrix = matrix1 / matrix2
print(div_matrix)
# Out:
# tensor([[0.2000, 0.3333],
#         [0.4286, 0.5000]])

# %%
torch.add(matrix1, matrix2)
# Out:
# tensor([[ 6.,  8.],
#         [10., 12.]])

# %%
torch.sub(matrix1, matrix2)
# Out:
# tensor([[-4., -4.],
#         [-4., -4.]])

# %%
torch.mul(matrix1, matrix2)
# Out:
# tensor([[ 5., 12.],
#         [21., 32.]])

# %%
torch.div(matrix1, matrix2)
# Out:
# tensor([[0.2000, 0.3333],
#         [0.4286, 0.5000]])

# %% [markdown]
# - 행렬 곱을 위해서는 `@` 연산 기호나 `torch.matmul` 함수를 사용하여야 함

# %%
matmul_matrix=matrix1 @ matrix2
print(matmul_matrix)
# Out:
# tensor([[19., 22.],
#         [43., 50.]])

# %%
torch.matmul(matrix1, matrix2)
# Out:
# tensor([[19., 22.],
#         [43., 50.]])

# %% [markdown]
# # Tensor
# - Vector를 1차원, Matrix를 2차원이라고 한다면, **Tensor는 3차원 이상의 배열을 의미**
#   - 그냥 Vector, Matrix, Tensor를 전부 Tensor로 지칭하기도 함

# %%
tensor1 = torch.tensor([[[1., 2.], 
                         [3., 4.]], 
                        [[5., 6.], 
                         [7., 8.]]])
print(tensor1)
# Out:
# tensor([[[1., 2.],
#          [3., 4.]],
#
#         [[5., 6.],
#          [7., 8.]]])

# %%
tensor2 = torch.tensor([[[9., 10.], 
                         [11., 12.]], 
                        [[13., 14.],
                         [15., 16.]]])
print(tensor2)
# Out:
# tensor([[[ 9., 10.],
#          [11., 12.]],
#
#         [[13., 14.],
#          [15., 16.]]])

# %%
sum_tensor = tensor1 + tensor2
print(sum_tensor)
# Out:
# tensor([[[10., 12.],
#          [14., 16.]],
#
#         [[18., 20.],
#          [22., 24.]]])

# %%
sub_tensor = tensor1 - tensor2
print(sub_tensor)
# Out:
# tensor([[[-8., -8.],
#          [-8., -8.]],
#
#         [[-8., -8.],
#          [-8., -8.]]])

# %%
mul_tensor = tensor1 * tensor2
print(mul_tensor)
# Out:
# tensor([[[  9.,  20.],
#          [ 33.,  48.]],
#
#         [[ 65.,  84.],
#          [105., 128.]]])

# %%
div_tensor = tensor1 / tensor2
print(div_tensor)
# Out:
# tensor([[[0.1111, 0.2000],
#          [0.2727, 0.3333]],
#
#         [[0.3846, 0.4286],
#          [0.4667, 0.5000]]])

# %%
torch.add(tensor1, tensor2)
# Out:
# tensor([[[10., 12.],
#          [14., 16.]],
#
#         [[18., 20.],
#          [22., 24.]]])

# %%
torch.sub(tensor1, tensor2)
# Out:
# tensor([[[-8., -8.],
#          [-8., -8.]],
#
#         [[-8., -8.],
#          [-8., -8.]]])

# %%
torch.mul(tensor1, tensor2)
# Out:
# tensor([[[  9.,  20.],
#          [ 33.,  48.]],
#
#         [[ 65.,  84.],
#          [105., 128.]]])

# %%
torch.div(tensor1, tensor2)
# Out:
# tensor([[[0.1111, 0.2000],
#          [0.2727, 0.3333]],
#
#         [[0.3846, 0.4286],
#          [0.4667, 0.5000]]])

# %%
tensor1
# Out:
# tensor([[[1., 2.],
#          [3., 4.]],
#
#         [[5., 6.],
#          [7., 8.]]])

# %%
tensor2
# Out:
# tensor([[[ 9., 10.],
#          [11., 12.]],
#
#         [[13., 14.],
#          [15., 16.]]])

# %%
torch.matmul(tensor1, tensor2)
# Out:
# tensor([[[ 31.,  34.],
#          [ 71.,  78.]],
#
#         [[155., 166.],
#          [211., 226.]]])

# %%
tensor1.matmul(tensor2)
# Out:
# tensor([[[ 31.,  34.],
#          [ 71.,  78.]],
#
#         [[155., 166.],
#          [211., 226.]]])

# %%
tensor1 @ tensor2
# Out:
# tensor([[[ 31.,  34.],
#          [ 71.,  78.]],
#
#         [[155., 166.],
#          [211., 226.]]])

# %% [markdown]
# # 역전파를 통해 MLP의 Parameter를 Update하는 코드 예시

# %%
import torch

if torch.cuda.is_available(): # 현재 파이썬이 실행되고 있는 환경에서 torch 모듈을 이용할 때 GPU를 이용할 수 있는지 확인하는 함수
    DEVICE = torch.device('cuda') # 참이면 'cuda' 이용
else:
    DEVICE = torch.device('cpu') # 거짓이면 'cpu' 이용

BATCH_SIZE = 64 # 파라미터를 업데이트할 때 계산되는 데이터의 개수. 즉, 64개의 데이터로 Output을 계산하여 이를 바탕으로 Loss를 산출하여 파라미터를 1회 Update함, chanel로 생각???
INPUT_SIZE = 1000 # Input 레이어의 노드 수. BATCH_SIZE와 혼동하지 말 것. 크기가 1000인 벡터 64개로 Output 계산
HIDDEN_SIZE = 100 # Hidden 레이어의 노드 수
OUTPUT_SIZE = 10 # Output 레이어의 노드 수 - 분류문제라면 class 수, 회귀문제면 1개

# (BATCH_SIZE, INPUT_SIZE)의 크기를 갖는 Input 데이터를 생성하기 위해 torch.randn 함수 활용(표준정규분포를 따르는 Element들로 Tensor(행렬, 벡터 등)가 구성되도록 하는 함수)
# device는 위에서 정의한 DEVICE 활용, 데이터 Type은 실수(torch.float)
# Gradient 계산이 필요 없는 부분이기 때문에 requires_grad = False (Gradient 계산은 Parameter update 할 때 필요) 
x = torch.randn(BATCH_SIZE, 
                INPUT_SIZE, 
                device = DEVICE, 
                dtype = torch.float, 
                requires_grad = False)  

# (BATCH_SIZE, OUTPUT_SIZE)의 크기를 갖는 정답 데이터도 같은 방식으로 임의로 생성
y = torch.randn(BATCH_SIZE, 
                OUTPUT_SIZE, 
                device = DEVICE,
                dtype = torch.float, 
                requires_grad = False)  

# (INPUT_SIZE, HIDDEN_SIZE)의 크기를 갖는 가중치 행렬 생성
# x(shape이 BATCH_SIZE,INPUT_SIZE)와 w1(shape이 INPUT_SIZE, HIDDEN_SIZE)의 행렬 곱(shape이 BATCH_SIZE, HIDDEN_SIZE)을 통해 Hidden 레이어의 노드 수 만큼 연산값이 만들어지게
# Update를 해야하는 대상이기 때문에 requires_grad = True 로 설정
w1 = torch.randn(INPUT_SIZE, 
                 HIDDEN_SIZE, 
                 device = DEVICE, 
                 dtype = torch.float,
                 requires_grad = True)

# (HIDDEN_SIZE, OUTPUT_SIZE)의 크기를 갖는 가중치 행렬 생성
# x와 w1의 행렬 곱을 통해 만들어진 Hidden 레이어의 연산 값들(shape이 BATCH_SIZE, HIDDEN_SIZE)과 w2(shape이 HIDDEN_SIZE, OUTPUT_SIZE)를 행렬 곱하여 
# Output 레이어의 노드 수 만큼 Output(shape이 BATCH_SIZE, OUTPUT_SIZE) 생성
# Update를 해야하는 대상이기 때문에 requires_grad = True 로 설정
w2 = torch.randn(HIDDEN_SIZE,
                 OUTPUT_SIZE, 
                 device = DEVICE,
                 dtype = torch.float,
                 requires_grad = True)  

# 학습 정도를 결정하는 learning_rate 설정
learning_rate = 1e-6                                           
for t in range(1, 501): # 500번 반복
    y_pred = x.mm(w1).clamp(min = 0).mm(w2) # x.mm(w1) : x와 w1의 행렬곱을 의미, clamp : min 값보다 작으면 min값으로, 아니면 그대로(ReLU와 같음)
                                            # x와 w1 행렬곱하고 그게 0보다 작으면 0으로, 아니면 그대로 하고 그거를 w2와 행렬곱한 것이 y의 예측값이다.
    loss = (y_pred - y).pow(2).sum() # pow(2):제곱, sum():행렬(Tensor)의 모든 element를 더함
    if t % 100 == 0:
        print("Iteration: ", t, "\t", "Loss: ", loss.item()) # loss.item(): tensor type을 Python number type으로 바꿔줌
    loss.backward() # Parameter Update에 사용되는 Gradient 계산                                          

    with torch.no_grad(): # 아래 코드들은 Gradient를 추가 계산하지 않고 고정시킨 상태에서 실행됨                                     
        w1 -= learning_rate * w1.grad # w1 Update
        w2 -= learning_rate * w2.grad # w2 Update              

        w1.grad.zero_() # w1에 저장되어 있는 Gradient를 0으로 초기화             
        w2.grad.zero_() # w2에 저장되어 있는 Gradient를 0으로 초기화
# Out:
# Iteration:  100 	 Loss:  264.80511474609375
# Iteration:  200 	 Loss:  0.7960764765739441
# Iteration:  300 	 Loss:  0.004462303593754768
# Iteration:  400 	 Loss:  0.00013200068497098982
# Iteration:  500 	 Loss:  2.5405777705600485e-05

# %%
# 방법 1
x = torch.tensor([2,3],dtype = torch.float)
y = 1
w1 = torch.tensor([[0.11,0.12],[0.21,0.08]], requires_grad = True)
w2 = torch.tensor([0.14,0.15], requires_grad = True)

h = torch.matmul(x,w1)
out = torch.matmul(h,w2)
loss = 1/2 * (out - y).pow(2)
learning_rate = 0.05
loss.backward()
with torch.no_grad() :
    w1 -= learning_rate * w1.grad
    w2 -= learning_rate * w2.grad
    
    w1.grad.zero_()
    w2.grad.zero_()

# %%
# 교수님꺼 나한테 맞게 변경한 것
x=torch.tensor([2.0,3.0], dtype=torch.float, requires_grad=False)
y=torch.tensor([1.0], dtype=torch.float, requires_grad=False)

w1= torch.tensor([[0.11,0.12],
                  [0.21,0.08]], requires_grad=True)
w2= torch.tensor([[0.14],
                  [0.15]], requires_grad=True)

learning_rate=0.05
for i in range(2):
  h=x@w1
  y_pred=h@w2

  loss=torch.sum(((1/2)*((y_pred-y).pow(2))))
  if i % 100==0:
    print('Iteration: ', i, '\t', 'Loss: ', loss.item())
  else:
    print('update after')
  print(w1)
  print(w2)
  print('y_pred',y_pred)
  print(str(i+1)+' step loss: ', loss)

  if i==0:
    loss.backward()
    with torch.no_grad():
      w1-=learning_rate * w1.grad
      w2-=learning_rate * w2.grad

      w1.grad.zero_()
      w2.grad.zero_()
# Out:
# Iteration:  0 	 Loss:  0.327240526676178
# tensor([[0.1100, 0.1200],
#         [0.2100, 0.0800]], requires_grad=True)
# tensor([[0.1400],
#         [0.1500]], requires_grad=True)
# y_pred tensor([0.1910], grad_fn=<SqueezeBackward3>)
# 1 step loss:  tensor(0.3272, grad_fn=<SumBackward0>)
# update after
# tensor([[0.1213, 0.1321],
#         [0.2270, 0.0982]], requires_grad=True)
# tensor([[0.1744],
#         [0.1694]], requires_grad=True)
# y_pred tensor([0.2557], grad_fn=<SqueezeBackward3>)
# 2 step loss:  tensor(0.2770, grad_fn=<SumBackward0>)

# %%
# 방법 2(교수님)
x= torch.tensor([[2.0,3.0]], requires_grad= False)
y= torch.tensor([[1.0]], requires_grad= False)

w1= torch.tensor([[0.11, 0.12],
                  [0.21,0.08]], requires_grad=True)
w2= torch.tensor([[0.14],
                  [0.15]], requires_grad=True)

learning_rate= 0.05
for t in range(2):
  hidden = x@w1
  print(hidden)
  y_pred = hidden @ w2
  print(y_pred)

  loss = torch.sum(((y_pred - y).pow(2))*(1/2))
  if t % 100 == 0:
    print('Iteration: ', t, '\t', 'Loss: ', loss.item())
  print(w1)
  print(w2)
  print('y_pred: ', y_pred)
  print(str(t+1)+' step loss: ', loss)

  if t ==0:
    loss.backward()
    with torch.no_grad():
      w1-=learning_rate*w1.grad
      w2-=learning_rate * w2.grad

      w1.grad.zero_()
      w2.grad.zero_()
# Out:
# tensor([[0.8500, 0.4800]], grad_fn=<MmBackward>)
# tensor([[0.1910]], grad_fn=<MmBackward>)
# Iteration:  0 	 Loss:  0.327240526676178
# tensor([[0.1100, 0.1200],
#         [0.2100, 0.0800]], requires_grad=True)
# tensor([[0.1400],
#         [0.1500]], requires_grad=True)
# y_pred:  tensor([[0.1910]], grad_fn=<MmBackward>)
# 1 step loss:  tensor(0.3272, grad_fn=<SumBackward0>)
# tensor([[0.9236, 0.5589]], grad_fn=<MmBackward>)
# tensor([[0.2557]], grad_fn=<MmBackward>)
# tensor([[0.1213, 0.1321],
#         [0.2270, 0.0982]], requires_grad=True)
# tensor([[0.1744],
#         [0.1694]], requires_grad=True)
# y_pred:  tensor([[0.2557]], grad_fn=<MmBackward>)
# 2 step loss:  tensor(0.2770, grad_fn=<SumBackward0>)

# %%
# Iteration:  100 	 Loss:  976.0719604492188
# Iteration:  200 	 Loss:  5.061180114746094
# Iteration:  300 	 Loss:  0.04102771729230881
# Iteration:  400 	 Loss:  0.0006718397489748895
# Iteration:  500 	 Loss:  6.94335249136202e-05

# %%
import torch
x=torch.tensor([[2.,3.]], requires_grad=False)
y=torch.tensor([[1.]], requires_grad=False)

w1=torch.tensor([[0.11,0.12],
                 [0.21,0.08]], requires_grad=True)
w2=torch.tensor([[.14],[.15]],requires_grad=True)
learning_rate=.05
for i in range(2):
  h=x @ w1
  print('h:', h)
  y_pred=h @ w2
  print('y_pred:',y_pred)
  
  loss=torch.sum((1/2)*((y_pred-y).pow(2)))
  if i %100==0:
    print('Iteration: ', i, '\t', 'Loss: ', loss.item())
  print('w1: ',w1)
  print('w2: ', w2)
  print('loss:', loss)
  if i==0:
    loss.backward()
    with torch.no_grad():
      w1-= learning_rate * w1.grad
      w2-= learning_rate * w2.grad

      w1.grad.zero_()
      w2.grad.zero_()
# Out:
# h: tensor([[0.8500, 0.4800]], grad_fn=<MmBackward>)
# y_pred: tensor([[0.1910]], grad_fn=<MmBackward>)
# Iteration:  0 	 Loss:  0.327240526676178
# w1:  tensor([[0.1100, 0.1200],
#         [0.2100, 0.0800]], requires_grad=True)
# w2:  tensor([[0.1400],
#         [0.1500]], requires_grad=True)
# loss: tensor(0.3272, grad_fn=<SumBackward0>)
# h: tensor([[0.9236, 0.5589]], grad_fn=<MmBackward>)
# y_pred: tensor([[0.2557]], grad_fn=<MmBackward>)
# w1:  tensor([[0.1213, 0.1321],
#         [0.2270, 0.0982]], requires_grad=True)
# w2:  tensor([[0.1744],
#         [0.1694]], requires_grad=True)
# loss: tensor(0.2770, grad_fn=<SumBackward0>)

# %%
import torch

x=torch.tensor([[2., 3.]],requires_grad=False)
y=torch.tensor([[1.]],requires_grad=False)

w1=torch.tensor([[.11,.12],
                 [.21,.08]],requires_grad=True)
w2=torch.tensor([[.14],
                 [.15]],requires_grad=True)
learning_rate=.05

for i in range(2):
  h=x @ w1
  y_pred=h @ w2
  loss = torch.sum((1/2)*((y_pred-y).pow(2)))
  print(i,'번째 시도')
  print('hidden :',h)
  print('y_pred :', y_pred)
  print('loss :', loss.item())
  print('w1: ', w1)
  print('w2 :', w2)
  if i==0:
    loss.backward()
    with torch.no_grad():
      w1-=learning_rate * w1.grad
      w2-=learning_rate * w2.grad

      w1.grad.zero_()
      w2.grad.zero_()
# Out:
# 0 번째 시도
# hidden : tensor([[0.8500, 0.4800]], grad_fn=<MmBackward>)
# y_pred : tensor([[0.1910]], grad_fn=<MmBackward>)
# loss : 0.327240526676178
# w1:  tensor([[0.1100, 0.1200],
#         [0.2100, 0.0800]], requires_grad=True)
# w2 : tensor([[0.1400],
#         [0.1500]], requires_grad=True)
# 1 번째 시도
# hidden : tensor([[0.9236, 0.5589]], grad_fn=<MmBackward>)
# y_pred : tensor([[0.2557]], grad_fn=<MmBackward>)
# loss : 0.2769571840763092
# w1:  tensor([[0.1213, 0.1321],
#         [0.2270, 0.0982]], requires_grad=True)
# w2 : tensor([[0.1744],
#         [0.1694]], requires_grad=True)
