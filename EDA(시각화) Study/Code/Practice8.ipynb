# %% [markdown]
# #### 아래 데이터는 2019년 4월 1일부터 15일까지 모바일 웹 사용자 패널의 로그기록이다. 아래 과정에 따라 분석을 진행하시오.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("./data/xView_201904_01_15.csv")

# %% [markdown]
# #### Time stamp 전처리 및 요일/시간 변수 생성

# %%
data['Time Stamp'] = pd.to_datetime(data['Time Stamp'])
data['Weekday'] = data['Time Stamp'].dt.weekday
data['Hour'] = data['Time Stamp'].dt.hour

data.head()
# Out:
#       KMID          Time Stamp  \
# 0  KM00002 2019-04-01 13:09:38
# 1  KM00002 2019-04-02 12:10:28
# 2  KM00002 2019-04-02 15:27:21
# 3  KM00002 2019-04-02 15:27:34
# 4  KM00002 2019-04-03 12:03:12
#
#                                                  URL           Full Title  \
# 0  https://m.search.naver.com/search.naver?query=...  한양대학교 날씨 : 네이버 통합검색
# 1  https://m.search.naver.com/search.naver?query=...  한양대학교 날씨 : 네이버 통합검색
# 2  https://m.search.naver.com/search.naver?query=...       파파고 : 네이버 통합검색
# 3                          https://papago.naver.com/               Papago
# 4  https://m.search.naver.com/search.naver?query=...  한양대학교 날씨 : 네이버 통합검색
#
#    Weekday  Hour
# 0        0    13
# 1        1    12
# 2        1    15
# 3        1    15
# 4        2    12

# %% [markdown]
# #### Session ID 생성

# %%
data.sort_values(by=['KMID','Time Stamp'],inplace=True)

# %%
def add_newsession(df):
    df['Newsession'] = df['Time Stamp'].diff()>pd.Timedelta(minutes=20)
    df['Newsession'].iloc[0] = True
    return df
    
data = data.groupby('KMID').apply(add_newsession)

# %%
data['SessionID'] = data['Newsession'].cumsum()

# %% [markdown]
# #### Session time 생성
# - 각 session의 최대 시간과 최소 시간의 차이를 계산하여 초 단위로  SessionTime 변수 생성

# %%
data_session=data.groupby('SessionID').first()

# %%
data_session
# Out:
#               KMID          Time Stamp  \
# SessionID
# 1          KM00002 2019-04-01 13:09:38
# 2          KM00002 2019-04-02 12:10:28
# 3          KM00002 2019-04-02 15:27:21
# 4          KM00002 2019-04-03 12:03:12
# 5          KM00002 2019-04-03 12:25:58
# ...            ...                 ...
# 89379      KM17248 2019-04-11 10:36:21
# 89380      KM17248 2019-04-11 13:41:23
# 89381      KM17248 2019-04-13 23:54:57
# 89382      KM17248 2019-04-14 17:21:08
# 89383      KM17248 2019-04-15 19:53:38
#
#                                                          URL  \
# SessionID
# 1          https://m.search.naver.com/search.naver?query=...
# 2          https://m.search.naver.com/search.naver?query=...
# 3          https://m.search.naver.com/search.naver?query=...
# 4          https://m.search.naver.com/search.naver?query=...
# 5          https://m.search.naver.com/search.naver?query=...
# ...                                                      ...
# 89379      https://m.search.naver.com/search.naver?where=...
# 89380      https://m.search.naver.com/search.naver?query=...
# 89381      https://m.news.naver.com/read.nhn?mode=LSD&mid...
# 89382                        https://m.me.naver.com/noti.nhn
# 89383        https://n.news.naver.com/article/025/0002899616
#
#                                      Full Title  Weekday  Hour  Newsession
# SessionID
# 1                           한양대학교 날씨 : 네이버 통합검색        0    13        True
# 2                           한양대학교 날씨 : 네이버 통합검색        1    12        True
# 3                                파파고 : 네이버 통합검색        1    15        True
# 4                           한양대학교 날씨 : 네이버 통합검색        2    12        True
# 5                                회송행 : 네이버 통합검색        2    12        True
# ...                                         ...      ...   ...         ...
# 89379                        옥션 싱글데이 : 네이버 통합검색        3    10        True
# 89380                         갈현동 날씨 : 네이버 통합검색        3    13        True
# 89381      '세월호 5주기' 추모물결…광화문 수놓은 거대한 노란 리본(종합)        5    23        True
# 89382                                    네이버 알림        6    17        True
# 89383             죽음 부른 유튜브 먹방···주먹밥 한입에 넣고 질식사        0    19        True
#
# [89383 rows x 7 columns]

# %%
data_session['SessionTime']=data.groupby('SessionID')['Time Stamp'].max()-data.groupby('SessionID')['Time Stamp'].min()

# %%
data_session['SessionTime']=data_session['SessionTime'].dt.total_seconds()

# %% [markdown]
# - SessionID를 index에서 변수로 변환
# - Time Stamp를 index로 설정

# %%
data_session=data_session.reset_index()
data_session=data_session.set_index('Time Stamp')

# %%
data_session
# Out:
#                      SessionID     KMID  \
# Time Stamp
# 2019-04-01 13:09:38          1  KM00002
# 2019-04-02 12:10:28          2  KM00002
# 2019-04-02 15:27:21          3  KM00002
# 2019-04-03 12:03:12          4  KM00002
# 2019-04-03 12:25:58          5  KM00002
# ...                        ...      ...
# 2019-04-11 10:36:21      89379  KM17248
# 2019-04-11 13:41:23      89380  KM17248
# 2019-04-13 23:54:57      89381  KM17248
# 2019-04-14 17:21:08      89382  KM17248
# 2019-04-15 19:53:38      89383  KM17248
#
#                                                                    URL  \
# Time Stamp
# 2019-04-01 13:09:38  https://m.search.naver.com/search.naver?query=...
# 2019-04-02 12:10:28  https://m.search.naver.com/search.naver?query=...
# 2019-04-02 15:27:21  https://m.search.naver.com/search.naver?query=...
# 2019-04-03 12:03:12  https://m.search.naver.com/search.naver?query=...
# 2019-04-03 12:25:58  https://m.search.naver.com/search.naver?query=...
# ...                                                                ...
# 2019-04-11 10:36:21  https://m.search.naver.com/search.naver?where=...
# 2019-04-11 13:41:23  https://m.search.naver.com/search.naver?query=...
# 2019-04-13 23:54:57  https://m.news.naver.com/read.nhn?mode=LSD&mid...
# 2019-04-14 17:21:08                    https://m.me.naver.com/noti.nhn
# 2019-04-15 19:53:38    https://n.news.naver.com/article/025/0002899616
#
#                                                Full Title  Weekday  Hour  \
# Time Stamp
# 2019-04-01 13:09:38                   한양대학교 날씨 : 네이버 통합검색        0    13
# 2019-04-02 12:10:28                   한양대학교 날씨 : 네이버 통합검색        1    12
# 2019-04-02 15:27:21                        파파고 : 네이버 통합검색        1    15
# 2019-04-03 12:03:12                   한양대학교 날씨 : 네이버 통합검색        2    12
# 2019-04-03 12:25:58                        회송행 : 네이버 통합검색        2    12
# ...                                                   ...      ...   ...
# 2019-04-11 10:36:21                    옥션 싱글데이 : 네이버 통합검색        3    10
# 2019-04-11 13:41:23                     갈현동 날씨 : 네이버 통합검색        3    13
# 2019-04-13 23:54:57  '세월호 5주기' 추모물결…광화문 수놓은 거대한 노란 리본(종합)        5    23
# 2019-04-14 17:21:08                                네이버 알림        6    17
# 2019-04-15 19:53:38         죽음 부른 유튜브 먹방···주먹밥 한입에 넣고 질식사        0    19
#
#                      Newsession  SessionTime
# Time Stamp
# 2019-04-01 13:09:38        True          0.0
# 2019-04-02 12:10:28        True          0.0
# 2019-04-02 15:27:21        True         13.0
# 2019-04-03 12:03:12        True          0.0
# 2019-04-03 12:25:58        True          0.0
# ...                         ...          ...
# 2019-04-11 10:36:21        True          0.0
# 2019-04-11 13:41:23        True          0.0
# 2019-04-13 23:54:57        True          0.0
# 2019-04-14 17:21:08        True        128.0
# 2019-04-15 19:53:38        True        110.0
#
# [89383 rows x 8 columns]

# %% [markdown]
# #### 시간별 Session Time 평균 및 시계열 분해
# - 시간 단위의 Session Time의 평균 생성
# - 시간 단위 시계열을 분해하여 24시간의 계절성 그래프와 추세 그래프 프린트

# %%
data_mean=data_session.resample('H').SessionTime.mean()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result1 = seasonal_decompose(data_mean, model='additive', 
                            period=24)
result1.plot()
plt.show()

# %%
result1.trend.plot()
# Out:
# <AxesSubplot:xlabel='Time Stamp'>

# %%
result1.seasonal.plot()
# Out:
# <AxesSubplot:xlabel='Time Stamp'>

# %%
result1.seasonal[:24].plot()
plt.show()

# %% [markdown]
# #### 가장 session이 많은 유저 분석
# - 가장 Session의 개수가 많은 유저는 누구인가?

# %%
data_session.KMID.value_counts().index[0]
# Out:
# 'KM01011'

# %% [markdown]
# - 해당 유저의 데이터를 추출하고 위에서 한 것과 같이 Session ID 변수 생성 후 Time Stamp를 index로 설정

# %%
data_id = data_session[data_session.KMID=='KM01011']

# %% [markdown]
# - 시간 단위의 session time의 합계 계산

# %%
data_user=data_id.resample('H')['SessionTime'].mean().fillna(0)

# %% [markdown]
# - 위에서 계산한 시간 단위의 session time의 합계를 사용하여 시계열 분해

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result2 = seasonal_decompose(data_user, model='additive', 
                            period=24)
result2.plot()
plt.show()

# %%
result1.trend.plot() ## 평균 트랜드
result2.trend.plot() ## 개인의 시간별 평균
plt.legend(['mean trend','KM01011 trend'])
plt.show()

# %% [markdown]
# - 위의 분해 시계열에서 추세를 추출하고 이를 사용하여 이동평균(window=10)과 지수평활(alpha=0.2)를 계산하여 추세와 함께 그래프 프린트

# %%
result2.trend.plot() ## 개인의 시간별 평균
result2.trend.rolling(10,center=True).mean().plot()
result2.trend.ewm(alpha=0.2, adjust=False).mean().plot()
plt.legend(['normal','rolling','ewm'])
plt.show()

# %%
trend_id= pd.DataFrame({
    'trend':result2.trend,
    'MA10':result2.trend.rolling(10,center=True).mean(),
    'EWM0.2':result2.trend.ewm(alpha=0.2, adjust=False).mean()
})

# %%
trend_id.plot(figsize=(12,8))
plt.show()

# %% [markdown]
# #### 쇼핑 로그 분석
# - Full Title에 '쇼핑'이란 단어가 포함된 데이터를 추출하여 저장

# %%
data_shopping = data.loc[data['Full Title'].str.contains('쇼핑')]

# %% [markdown]
# - 요일별 전체 로그 개수를 bar graph로 표현

# %%
data.groupby('Weekday').size().plot.bar()
plt.show()

# %% [markdown]
# - 요일별 쇼핑로그의 개수를 bar graph로 프린트

# %%
data_shopping.groupby('Weekday').size().plot.bar()
plt.show()

# %% [markdown]
# - 요일별 쇼핑로그의 비율(분모: 요일별 전체 로그 개수)를 bar graph로 프린트

# %%
data_shopping.groupby('Weekday').size().div(data.groupby('Weekday').size()).plot.bar()
plt.show()

# %% [markdown]
# - 요일별 session time의 평균을 bar graph로 표현

# %%
data_session.groupby('Weekday')['SessionTime'].mean().plot.bar()
plt.title('weekday mean')
plt.show()
